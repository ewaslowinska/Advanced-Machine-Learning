# %% [markdown]
# ## Setting up the Data
# This assignment is based on Deepayan137's code from "Adapting-OCR" github repository. The dataset used comes from Kaggle's "License Plate Characters - Detection OCR".
#
# The imports stayed the same as in the original code. I only added BeautifulSoup for reading the XML files

# %%
import os
import sys
import pdb
import six
import random
import lmdb
from PIL import Image
import numpy as np
import math
from collections import OrderedDict
from itertools import chain
import logging


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import sampler
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from torch.nn.utils.clip_grad import clip_grad_norm_
from torch.utils.data import random_split
sys.path.insert(0, '../')
from src.utils.utils import AverageMeter, Eval, OCRLabelConverter
from src.utils.utils import EarlyStopping, gmkdir
from src.optim.optimizer import STLR
from src.utils.utils import gaussian
from tqdm import *
from bs4 import BeautifulSoup
# Out:
# /Users/ewaslowinska/Library/Python/3.10/lib/python/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/ewaslowinska/Library/Python/3.10/lib/python/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c106detail19maybe_wrap_dim_slowExxb
#   Referenced from: /Users/ewaslowinska/Library/Python/3.10/lib/python/site-packages/torchvision/image.so
#   Expected in: /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/lib/libc10.dylib
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# ## SynthDataset and SynthCollator
# I adjusted the dataset and collator classes to fit the new data. The dataset class takes the filenames of images and, based on them, chooses their respective XML files. From these files, it extracts the labels

# %%
class SynthDataset(Dataset):
    def __init__(self, opt):
        super(SynthDataset, self).__init__()
        self.imagepath = os.path.join(opt['path'], opt['imgdir'])
        self.labelpath = os.path.join(opt['path'], opt['labeldir'])
        self.images = os.listdir(self.imagepath)
        self.labels = os.listdir(self.labelpath)
        self.nSamples = len(self.images)
        f = lambda x: os.path.join(self.imagepath, x)
        self.imagepaths = list(map(f, self.images))
        g = lambda x: os.path.join(self.labelpath, x)
        self.labelpaths = list(map(g, self.labels))
       	transform_list =  [transforms.Grayscale(1),
                            transforms.ToTensor(), 
                            transforms.Normalize((0.5,), (0.5,))]
        self.transform = transforms.Compose(transform_list)
        self.collate_fn = SynthCollator()

    def __len__(self):
        return self.nSamples

    def __getitem__(self, index):
        assert index <= len(self), 'index range error'
        imagepath = self.imagepaths[index]
        imagefile = os.path.basename(imagepath)
        img = Image.open(imagepath)

        if self.transform is not None:
            img = self.transform(img)

        labelpath = os.path.join(self.labelpath, imagefile.replace('.png', '.xml'))

        string = ''
        with open(labelpath, 'r', encoding='utf-8') as f:
            data = f.read()

        bs_data = BeautifulSoup(data, 'xml')
        b_name = bs_data.find_all('name')

        for name in b_name:
            string += name.text

        item = {'img': img, 'idx': index, 'label': string}
        return item

# %% [markdown]
# The collator resizes the images to 32x100

# %%
class SynthCollator(object):
    
    def __call__(self, batch):
        images = [item['img'] for item in batch]
        resized_images = torch.stack([transforms.functional.resize(img, (32, 100)) for img in images])

        item = {'img': resized_images, 'idx': [item['idx'] for item in batch]}

        if 'label' in batch[0].keys():
            labels = [item['label'] for item in batch if item['label']]
            item['label'] = labels if labels else [''] * len(batch)

        return item

# %% [markdown]
# ## Defining our Model

# %%
class BidirectionalLSTM(nn.Module):

    def __init__(self, nIn, nHidden, nOut):
        super(BidirectionalLSTM, self).__init__()
        self.rnn = nn.LSTM(nIn, nHidden, bidirectional=True)
        self.embedding = nn.Linear(nHidden * 2, nOut)
    def forward(self, input):
        self.rnn.flatten_parameters()
        recurrent, _ = self.rnn(input)
        T, b, h = recurrent.size()
        t_rec = recurrent.view(T * b, h)
        output = self.embedding(t_rec)  # [T * b, nOut]
        output = output.view(T, b, -1)
        return output

class CRNN(nn.Module):

    def __init__(self, opt, leakyRelu=False):
        super(CRNN, self).__init__()

        assert opt['imgH'] % 16 == 0, 'imgH has to be a multiple of 16'

        ks = [3, 3, 3, 3, 3, 3, 2]
        ps = [1, 1, 1, 1, 1, 1, 0]
        ss = [1, 1, 1, 1, 1, 1, 1]
        nm = [64, 128, 256, 256, 512, 512, 512]

        cnn = nn.Sequential()

        def convRelu(i, batchNormalization=False):
            nIn = opt['nChannels'] if i == 0 else nm[i - 1]
            nOut = nm[i]
            cnn.add_module('conv{0}'.format(i),
                           nn.Conv2d(nIn, nOut, ks[i], ss[i], ps[i]))
            if batchNormalization:
                cnn.add_module('batchnorm{0}'.format(i), nn.BatchNorm2d(nOut))
            if leakyRelu:
                cnn.add_module('relu{0}'.format(i),
                               nn.LeakyReLU(0.2, inplace=True))
            else:
                cnn.add_module('relu{0}'.format(i), nn.ReLU(True))

        convRelu(0)
        cnn.add_module('pooling{0}'.format(0), nn.MaxPool2d(2, 2))  # 64x16x64
        convRelu(1)
        cnn.add_module('pooling{0}'.format(1), nn.MaxPool2d(2, 2))  # 128x8x32
        convRelu(2, True)
        convRelu(3)
        cnn.add_module('pooling{0}'.format(2),
                       nn.MaxPool2d((2, 2), (2, 1), (0, 1)))  # 256x4x16
        convRelu(4, True)
        convRelu(5)
        cnn.add_module('pooling{0}'.format(3),
                       nn.MaxPool2d((2, 2), (2, 1), (0, 1)))  # 512x2x16
        convRelu(6, True)  # 512x1x16
        self.cnn = cnn
        self.rnn = nn.Sequential()
        self.rnn = nn.Sequential(
            BidirectionalLSTM(opt['nHidden']*2, opt['nHidden'], opt['nHidden']),
            BidirectionalLSTM(opt['nHidden'], opt['nHidden'], opt['nClasses']))


    def forward(self, input):
        # conv features
        conv = self.cnn(input)
        b, c, h, w = conv.size()
        assert h == 1, "the height of conv must be 1"
        conv = conv.squeeze(2)
        conv = conv.permute(2, 0, 1)  # [w, b, c]
        # rnn features
        output = self.rnn(conv)
        output = output.transpose(1,0) #Tbh to bth
        return output

# %% [markdown]
# ## The CTC Loss

# %%
class CustomCTCLoss(torch.nn.Module):
    # T x B x H => Softmax on dimension 2
    def __init__(self, dim=2):
        super().__init__()
        self.dim = dim
        self.ctc_loss = torch.nn.CTCLoss(reduction='mean', zero_infinity=True)

    def forward(self, logits, labels,
            prediction_sizes, target_sizes):
        EPS = 1e-7
        loss = self.ctc_loss(logits, labels, prediction_sizes, target_sizes)
        loss = self.sanitize(loss)
        return self.debug(loss, logits, labels, prediction_sizes, target_sizes)
    
    def sanitize(self, loss):
        EPS = 1e-7
        if abs(loss.item() - float('inf')) < EPS:
            return torch.zeros_like(loss)
        if math.isnan(loss.item()):
            return torch.zeros_like(loss)
        return loss

    def debug(self, loss, logits, labels,
            prediction_sizes, target_sizes):
        if math.isnan(loss.item()):
            print("Loss:", loss)
            print("logits:", logits)
            print("labels:", labels)
            print("prediction_sizes:", prediction_sizes)
            print("target_sizes:", target_sizes)
            raise Exception("NaN loss obtained. But why?")
        return loss

# %% [markdown]
# ## The Training Loop

# %%
class OCRTrainer(object):
    def __init__(self, opt):
        super(OCRTrainer, self).__init__()
        self.data_train = opt['data_train']
        self.data_val = opt['data_val']
        self.model = opt['model']
        self.criterion = opt['criterion']
        self.optimizer = opt['optimizer']
        self.schedule = opt['schedule']
        self.converter = OCRLabelConverter(opt['alphabet'])
        self.evaluator = Eval()
        print('Scheduling is {}'.format(self.schedule))
        self.scheduler = CosineAnnealingLR(self.optimizer, T_max=opt['epochs'])
        self.batch_size = opt['batch_size']
        self.count = opt['epoch']
        self.epochs = opt['epochs']
        self.cuda = opt['cuda']
        self.collate_fn = opt['collate_fn']
        self.init_meters()

    def init_meters(self):
        self.avgTrainLoss = AverageMeter("Train loss")
        self.avgTrainCharAccuracy = AverageMeter("Train Character Accuracy")
        self.avgTrainWordAccuracy = AverageMeter("Train Word Accuracy")
        self.avgValLoss = AverageMeter("Validation loss")
        self.avgValCharAccuracy = AverageMeter("Validation Character Accuracy")
        self.avgValWordAccuracy = AverageMeter("Validation Word Accuracy")

    def forward(self, x):
        logits = self.model(x)
        return logits.transpose(1, 0)

    def loss_fn(self, logits, targets, pred_sizes, target_sizes):
        loss = self.criterion(logits, targets, pred_sizes, target_sizes)
        return loss

    def step(self):
        self.max_grad_norm = 0.05
        clip_grad_norm_(self.model.parameters(), self.max_grad_norm)
        self.optimizer.step()
    
    def schedule_lr(self):
        if self.schedule:
            self.scheduler.step()

    def _run_batch(self, batch, report_accuracy=False, validation=False):
        input_, targets = batch['img'], batch['label']
        targets, lengths = self.converter.encode(targets)
        logits = self.forward(input_)
        logits = logits.contiguous().cpu()
        logits = torch.nn.functional.log_softmax(logits, 2)
        T, B, H = logits.size()
        pred_sizes = torch.LongTensor([T for i in range(B)])
        targets= targets.view(-1).contiguous()
        loss = self.loss_fn(logits, targets, pred_sizes, lengths)
        if report_accuracy:
            probs, preds = logits.max(2)
            preds = preds.transpose(1, 0).contiguous().view(-1)
            sim_preds = self.converter.decode(preds.data, pred_sizes.data, raw=False)
            ca = np.mean((list(map(self.evaluator.char_accuracy, list(zip(sim_preds, batch['label']))))))
            wa = np.mean((list(map(self.evaluator.word_accuracy, list(zip(sim_preds, batch['label']))))))
        return loss, ca, wa

    def run_epoch(self, validation=False):
        if not validation:
            loader = self.train_dataloader()
            pbar = tqdm(loader, desc='Epoch: [%d]/[%d] Training'%(self.count, 
                self.epochs), leave=True)
            self.model.train()
        else:
            loader = self.val_dataloader()
            pbar = tqdm(loader, desc='Validating', leave=True)
            self.model.eval()
        outputs = []
        for batch_nb, batch in enumerate(pbar):
            if not validation:
                output = self.training_step(batch)
            else:
                output = self.validation_step(batch)
            pbar.set_postfix(output)
            outputs.append(output)
        self.schedule_lr()
        if not validation:
            result = self.train_end(outputs)
        else:
            result = self.validation_end(outputs)
        return result

    def training_step(self, batch):
        loss, ca, wa = self._run_batch(batch, report_accuracy=True)
        self.optimizer.zero_grad()
        loss.backward()
        self.step()
        
        output = OrderedDict({
            'loss': abs(loss.item()),
            'train_ca': ca.item(),
            'train_wa': wa.item()
            })
        return output

    def validation_step(self, batch):
        loss, ca, wa = self._run_batch(batch, report_accuracy=True, validation=True)
        output = OrderedDict({
            'val_loss': abs(loss.item()),
            'val_ca': ca.item(),
            'val_wa': wa.item()
            })
        return output

    def train_dataloader(self):
        # logging.info('training data loader called')
        loader = torch.utils.data.DataLoader(self.data_train,
                batch_size=self.batch_size,
                collate_fn=self.collate_fn,
                shuffle=True)
        return loader
        
    def val_dataloader(self):
        # logging.info('val data loader called')
        loader = torch.utils.data.DataLoader(self.data_val,
                batch_size=self.batch_size,
                collate_fn=self.collate_fn)
        return loader

    def train_end(self, outputs):
        for output in outputs:
            self.avgTrainLoss.add(output['loss'])
            self.avgTrainCharAccuracy.add(output['train_ca'])
            self.avgTrainWordAccuracy.add(output['train_wa'])

        train_loss_mean = abs(self.avgTrainLoss.compute())
        train_ca_mean = self.avgTrainCharAccuracy.compute()
        train_wa_mean = self.avgTrainWordAccuracy.compute()

        result = {'train_loss': train_loss_mean, 'train_ca': train_ca_mean,
        'train_wa': train_wa_mean}
        # result = {'progress_bar': tqdm_dict, 'log': tqdm_dict, 'val_loss': train_loss_mean}
        return result

    def validation_end(self, outputs):
        for output in outputs:
            self.avgValLoss.add(output['val_loss'])
            self.avgValCharAccuracy.add(output['val_ca'])
            self.avgValWordAccuracy.add(output['val_wa'])

        val_loss_mean = abs(self.avgValLoss.compute())
        val_ca_mean = self.avgValCharAccuracy.compute()
        val_wa_mean = self.avgValWordAccuracy.compute()

        result = {'val_loss': val_loss_mean, 'val_ca': val_ca_mean,
        'val_wa': val_wa_mean}
        return result

# %% [markdown]
# ## Putting Everything Together

# %%
class Learner(object):
    def __init__(self, model, optimizer, savepath=None, resume=False):
        self.model = model
        self.optimizer = optimizer
        self.savepath = os.path.join(savepath, 'best.ckpt')
        self.cuda = torch.cuda.is_available() 
        self.cuda_count = torch.cuda.device_count()
        if self.cuda:
            self.model = self.model.cuda()
        self.epoch = 0
        if self.cuda_count > 1:
            print("Let's use", torch.cuda.device_count(), "GPUs!")
            self.model = nn.DataParallel(self.model)
        self.best_score = None
        if resume and os.path.exists(self.savepath):
            self.checkpoint = torch.load(self.savepath)
            self.epoch = self.checkpoint['epoch']
            self.best_score=self.checkpoint['best']
            self.load()
        else:
            print('checkpoint does not exist')

    def fit(self, opt):
        opt['cuda'] = self.cuda
        opt['model'] = self.model
        opt['optimizer'] = self.optimizer
        logging.basicConfig(filename="%s/%s.csv" %(opt['log_dir'], opt['name']), level=logging.INFO)
        self.saver = EarlyStopping(self.savepath, patience=15, verbose=True, best_score=self.best_score)
        opt['epoch'] = self.epoch
        trainer = OCRTrainer(opt)
        
        for epoch in range(opt['epoch'], opt['epochs']):
            train_result = trainer.run_epoch()
            val_result = trainer.run_epoch(validation=True)
            trainer.count = epoch
            info = '%d, %.6f, %.6f, %.6f, %.6f, %.6f, %.6f'%(epoch, train_result['train_loss'], 
                val_result['val_loss'], train_result['train_ca'],  val_result['val_ca'],
                train_result['train_wa'], val_result['val_wa'])
            logging.info(info)
            self.val_loss = val_result['val_loss']
            print(self.val_loss)
            if self.savepath:
                self.save(epoch)
            if self.saver.early_stop:
                print("Early stopping")
                break

    def load(self):
        print('Loading checkpoint at {} trained for {} epochs'.format(self.savepath, self.checkpoint['epoch']))
        self.model.load_state_dict(self.checkpoint['state_dict'])
        if 'opt_state_dict' in self.checkpoint.keys():
            print('Loading optimizer')
            self.optimizer.load_state_dict(self.checkpoint['opt_state_dict'])

    def save(self, epoch):
        self.saver(self.val_loss, epoch, self.model, self.optimizer)

# %% [markdown]
# ### Defining the hyperparameters
#
# I added the label directory to arguments. With the original number of epochs, the output was the same for every picture, so I changed it to 100

# %%
alphabet = """Only thewigsofrcvdampbkuq.$A-210xT5'MDL,RYHJ"ISPWENj&BC93VGFKz();#:!7U64Q8?+*ZX/%"""
args = {
    'name':'exp1',
    'path':'../LP-characters',
    'imgdir': 'images/train',
    'labeldir': 'annotations/train',
    'imgH':32,
    'nChannels':1,
    'nHidden':256,
    'nClasses':len(alphabet),
    'lr':0.001,
    'epochs':100,
    'batch_size':8,
    'save_dir':'../checkpoints/',
    'log_dir':'../logs',
    'resume':False,
    'cuda':False,
    'schedule':False
    
}

data = SynthDataset(args)
args['collate_fn'] = SynthCollator()
train_split = int(0.8*len(data))
val_split = len(data) - train_split
args['data_train'], args['data_val'] = random_split(data, (train_split, val_split))
print('Traininig Data Size:{}\nVal Data Size:{}'.format(
    len(args['data_train']), len(args['data_val'])))
args['alphabet'] = alphabet
model = CRNN(args)
args['criterion'] = CustomCTCLoss()
savepath = os.path.join(args['save_dir'], args['name'])
gmkdir(savepath)
gmkdir(args['log_dir'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
learner = Learner(model, optimizer, savepath=savepath, resume=args['resume'])
learner.fit(args)
# Out:
# Traininig Data Size:133
# Val Data Size:34
# checkpoint does not exist
# None
# Scheduling is False
# Epoch: [0]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.28it/s, loss=3.37, train_ca=0, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.62it/s, val_loss=3.88, val_ca=0, val_wa=0]
# 3.5511828899383544
# Validation loss decreased (inf --> 3.551183).  Saving model ...
# Epoch: [0]/[100] Training: 100%|██████████| 17/17 [00:10<00:00,  1.55it/s, loss=2.62, train_ca=0, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.45it/s, val_loss=3.89, val_ca=0, val_wa=0]
# 3.5070923566818237
# Validation loss decreased (3.551183 --> 3.507092).  Saving model ...
# Epoch: [1]/[100] Training: 100%|██████████| 17/17 [00:17<00:00,  1.03s/it, loss=3.4, train_ca=2, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:02<00:00,  2.47it/s, val_loss=3.7, val_ca=5.56, val_wa=0]
# 3.4350260575612386
# Validation loss decreased (3.507092 --> 3.435026).  Saving model ...
# Epoch: [2]/[100] Training: 100%|██████████| 17/17 [00:14<00:00,  1.17it/s, loss=3.11, train_ca=11, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.00it/s, val_loss=3.58, val_ca=0, val_wa=0]
# 3.3893051624298094
# Validation loss decreased (3.435026 --> 3.389305).  Saving model ...
# Epoch: [3]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.34it/s, loss=3.1, train_ca=0, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.87it/s, val_loss=3.75, val_ca=11.1, val_wa=0]
# 3.354880247116089
# Validation loss decreased (3.389305 --> 3.354880).  Saving model ...
# Epoch: [4]/[100] Training: 100%|██████████| 17/17 [00:15<00:00,  1.13it/s, loss=3.02, train_ca=8.44, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.71it/s, val_loss=3.79, val_ca=10, val_wa=0]
# 3.328583494822184
# Validation loss decreased (3.354880 --> 3.328583).  Saving model ...
# Epoch: [5]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.37it/s, loss=2.82, train_ca=4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.56it/s, val_loss=3.6, val_ca=15.6, val_wa=0]
# 3.3045224121638705
# Validation loss decreased (3.328583 --> 3.304522).  Saving model ...
# Epoch: [6]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.42it/s, loss=2.92, train_ca=2.22, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.27it/s, val_loss=3.84, val_ca=11.1, val_wa=0]
# 3.2920175552368165
# Validation loss decreased (3.304522 --> 3.292018).  Saving model ...
# Epoch: [7]/[100] Training: 100%|██████████| 17/17 [00:17<00:00,  1.04s/it, loss=2.92, train_ca=6.22, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  2.77it/s, val_loss=3.61, val_ca=5.56, val_wa=0]
# 3.2655917485555013
# Validation loss decreased (3.292018 --> 3.265592).  Saving model ...
# Epoch: [8]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.33it/s, loss=3.19, train_ca=13.6, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  2.53it/s, val_loss=4.08, val_ca=5.56, val_wa=0]
# 3.2885825300216673
# EarlyStopping counter: (-3.265592 1 out of 15)
# Epoch: [9]/[100] Training: 100%|██████████| 17/17 [00:16<00:00,  1.01it/s, loss=2.63, train_ca=17.2, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:02<00:00,  2.07it/s, val_loss=3.63, val_ca=0, val_wa=0]
# 3.269588583165949
# EarlyStopping counter: (-3.265592 2 out of 15)
# Epoch: [10]/[100] Training: 100%|██████████| 17/17 [00:15<00:00,  1.12it/s, loss=2.91, train_ca=12.5, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.14it/s, val_loss=3.68, val_ca=11.1, val_wa=0]
# 3.248936978975932
# Validation loss decreased (3.265592 --> 3.248937).  Saving model ...
# Epoch: [11]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.29it/s, loss=2.72, train_ca=17.7, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.54it/s, val_loss=3.67, val_ca=11.1, val_wa=0]
# 3.230623806439913
# Validation loss decreased (3.248937 --> 3.230624).  Saving model ...
# Epoch: [12]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.30it/s, loss=2.58, train_ca=8, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.31it/s, val_loss=3.57, val_ca=15.6, val_wa=0]
# 3.213546453203474
# Validation loss decreased (3.230624 --> 3.213546).  Saving model ...
# Epoch: [13]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.32it/s, loss=2.97, train_ca=10.7, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.30it/s, val_loss=3.74, val_ca=11.1, val_wa=0]
# 3.2008366870880125
# Validation loss decreased (3.213546 --> 3.200837).  Saving model ...
# Epoch: [14]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.37it/s, loss=2.87, train_ca=12.7, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.32it/s, val_loss=3.72, val_ca=15.6, val_wa=0]
# 3.191276767849922
# Validation loss decreased (3.200837 --> 3.191277).  Saving model ...
# Epoch: [15]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.34it/s, loss=2.75, train_ca=17.7, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.39it/s, val_loss=3.69, val_ca=11.1, val_wa=0]
# 3.1817803719464473
# Validation loss decreased (3.191277 --> 3.181780).  Saving model ...
# Epoch: [16]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.31it/s, loss=2.88, train_ca=10.3, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.60it/s, val_loss=3.74, val_ca=21.1, val_wa=0]
# 3.1738238679038155
# Validation loss decreased (3.181780 --> 3.173824).  Saving model ...
# Epoch: [17]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.26it/s, loss=2.4, train_ca=19.8, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.19it/s, val_loss=3.79, val_ca=11.1, val_wa=0]
# 3.170078438206723
# Validation loss decreased (3.173824 --> 3.170078).  Saving model ...
# Epoch: [18]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.39it/s, loss=2.73, train_ca=10, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.55it/s, val_loss=3.63, val_ca=26.7, val_wa=0]
# 3.1609013414382936
# Validation loss decreased (3.170078 --> 3.160901).  Saving model ...
# Epoch: [19]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.35it/s, loss=2.54, train_ca=14.3, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.78it/s, val_loss=3.88, val_ca=11.1, val_wa=0]
# 3.1566430523282007
# Validation loss decreased (3.160901 --> 3.156643).  Saving model ...
# Epoch: [20]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.40it/s, loss=2.67, train_ca=10, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.03it/s, val_loss=3.69, val_ca=11.1, val_wa=0]
# 3.152000251683322
# Validation loss decreased (3.156643 --> 3.152000).  Saving model ...
# Epoch: [21]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.46it/s, loss=2.78, train_ca=16.1, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.81it/s, val_loss=3.78, val_ca=21.1, val_wa=0]
# 3.147812849542369
# Validation loss decreased (3.152000 --> 3.147813).  Saving model ...
# Epoch: [22]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.32it/s, loss=3.03, train_ca=11.4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.15it/s, val_loss=3.73, val_ca=11.1, val_wa=0]
# 3.143012930949529
# Validation loss decreased (3.147813 --> 3.143013).  Saving model ...
# Epoch: [23]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.37it/s, loss=3.25, train_ca=10, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.10it/s, val_loss=3.94, val_ca=11.1, val_wa=0]
# 3.142228151321411
# Validation loss decreased (3.143013 --> 3.142228).  Saving model ...
# Epoch: [24]/[100] Training: 100%|██████████| 17/17 [00:10<00:00,  1.61it/s, loss=3.14, train_ca=4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.22it/s, val_loss=3.72, val_ca=11.1, val_wa=0]
# 3.138948625784654
# Validation loss decreased (3.142228 --> 3.138949).  Saving model ...
# Epoch: [25]/[100] Training: 100%|██████████| 17/17 [00:10<00:00,  1.57it/s, loss=2.77, train_ca=12.9, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.92it/s, val_loss=3.72, val_ca=5.56, val_wa=0]
# 3.1354265990080656
# Validation loss decreased (3.138949 --> 3.135427).  Saving model ...
# Epoch: [26]/[100] Training: 100%|██████████| 17/17 [00:15<00:00,  1.07it/s, loss=2.61, train_ca=16.9, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.30it/s, val_loss=3.83, val_ca=11.1, val_wa=0]
# 3.132704835278647
# Validation loss decreased (3.135427 --> 3.132705).  Saving model ...
# Epoch: [27]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.53it/s, loss=2.49, train_ca=12, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.33it/s, val_loss=3.78, val_ca=11.1, val_wa=0]
# 3.1339917922842093
# EarlyStopping counter: (-3.132705 1 out of 15)
# Epoch: [28]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.29it/s, loss=2.5, train_ca=16.4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:02<00:00,  1.96it/s, val_loss=3.82, val_ca=11.1, val_wa=0]
# 3.1325493748982747
# Validation loss decreased (3.132705 --> 3.132549).  Saving model ...
# Epoch: [29]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.53it/s, loss=2.57, train_ca=12, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.17it/s, val_loss=3.71, val_ca=11.1, val_wa=0]
# 3.129383259434854
# Validation loss decreased (3.132549 --> 3.129383).  Saving model ...
# Epoch: [30]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.32it/s, loss=2.64, train_ca=14.7, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.33it/s, val_loss=3.96, val_ca=11.1, val_wa=0]
# 3.1289202332496644
# Validation loss decreased (3.129383 --> 3.128920).  Saving model ...
# Epoch: [31]/[100] Training: 100%|██████████| 17/17 [00:13<00:00,  1.26it/s, loss=2.38, train_ca=22.5, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.58it/s, val_loss=3.76, val_ca=16.7, val_wa=0]
# 3.1274495023669617
# Validation loss decreased (3.128920 --> 3.127450).  Saving model ...
# Epoch: [32]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.46it/s, loss=2.67, train_ca=14.3, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.14it/s, val_loss=6.31, val_ca=11.1, val_wa=0]
# 3.172500021317426
# EarlyStopping counter: (-3.127450 1 out of 15)
# Epoch: [33]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.43it/s, loss=2.98, train_ca=6.22, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.53it/s, val_loss=3.72, val_ca=26.7, val_wa=0]
# 3.168146502631051
# EarlyStopping counter: (-3.127450 2 out of 15)
# Epoch: [34]/[100] Training: 100%|██████████| 17/17 [00:10<00:00,  1.61it/s, loss=2.63, train_ca=12.9, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.50it/s, val_loss=3.92, val_ca=11.1, val_wa=0]
# 3.1662923812866213
# EarlyStopping counter: (-3.127450 3 out of 15)
# Epoch: [35]/[100] Training: 100%|██████████| 17/17 [00:10<00:00,  1.60it/s, loss=2.38, train_ca=14, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.61it/s, val_loss=3.85, val_ca=16.7, val_wa=0]
# 3.163943781723847
# EarlyStopping counter: (-3.127450 4 out of 15)
# Epoch: [36]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.44it/s, loss=2.71, train_ca=8, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.06it/s, val_loss=4.1, val_ca=11.1, val_wa=0]
# 3.1632049384870027
# EarlyStopping counter: (-3.127450 5 out of 15)
# Epoch: [37]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.35it/s, loss=2.7, train_ca=8, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.48it/s, val_loss=4.01, val_ca=11.1, val_wa=0]
# 3.1611954762385444
# EarlyStopping counter: (-3.127450 6 out of 15)
# Epoch: [38]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.36it/s, loss=2.67, train_ca=14.6, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.53it/s, val_loss=3.97, val_ca=16.7, val_wa=0]
# 3.158387520313263
# EarlyStopping counter: (-3.127450 7 out of 15)
# Epoch: [39]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.43it/s, loss=2.76, train_ca=16.4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.84it/s, val_loss=3.95, val_ca=11.1, val_wa=0]
# 3.1583663882278814
# EarlyStopping counter: (-3.127450 8 out of 15)
# Epoch: [40]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.39it/s, loss=2.66, train_ca=16.4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.21it/s, val_loss=3.9, val_ca=11.1, val_wa=0]
# 3.157296793801444
# EarlyStopping counter: (-3.127450 9 out of 15)
# Epoch: [41]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.47it/s, loss=2.58, train_ca=16.1, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.46it/s, val_loss=3.93, val_ca=22.2, val_wa=0]
# 3.1555702597595925
# EarlyStopping counter: (-3.127450 10 out of 15)
# Epoch: [42]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.40it/s, loss=2.73, train_ca=14.5, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.39it/s, val_loss=4.01, val_ca=11.1, val_wa=0]
# 3.153575483235446
# EarlyStopping counter: (-3.127450 11 out of 15)
# Epoch: [43]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.35it/s, loss=2.47, train_ca=21.4, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.38it/s, val_loss=3.92, val_ca=16.7, val_wa=0]
# 3.1521898810068767
# EarlyStopping counter: (-3.127450 12 out of 15)
# Epoch: [44]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.37it/s, loss=2.44, train_ca=20.9, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s, val_loss=3.91, val_ca=16.7, val_wa=0]
# 3.1506455338519554
# EarlyStopping counter: (-3.127450 13 out of 15)
# Epoch: [45]/[100] Training: 100%|██████████| 17/17 [00:12<00:00,  1.41it/s, loss=2.49, train_ca=14.5, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.15it/s, val_loss=3.85, val_ca=16.7, val_wa=0]
# 3.1490135608835423
# EarlyStopping counter: (-3.127450 14 out of 15)
# Epoch: [46]/[100] Training: 100%|██████████| 17/17 [00:11<00:00,  1.49it/s, loss=2.88, train_ca=18.9, train_wa=0]
# Validating: 100%|██████████| 5/5 [00:01<00:00,  4.38it/s, val_loss=4.06, val_ca=11.1, val_wa=0]
# 3.1494177023569745
# EarlyStopping counter: (-3.127450 15 out of 15)
# Early stopping

# %% [markdown]
# ## Evaluation and testing
#
# I added measures to evaluate the character predictions: precision, micro and macro recall, and micro and macro F1-score.
#
# The model doesn't work quite well. Its character accuracy is barely 13 percent. Its recall and F1-scores are below 10 percent, indicating that the model is missing a significant number of true positive instances. Only its precision is worthwhile, being almost 62 percent, which suggests that when the model predicts something, it's often correct. The predicted labels are often the same for different images , which could indicate a lack of diversity in the training data or a tendency to predict certain labels more frequently. The predicted labels are also usually much shorter than the ground truth labels, which means that the model is overly simplifying its predictions. The majority of output labels contain only the characters "K", "L", "M", "H", "1", "2", "6" and "0".  It suggests that the model might be biased or stuck in a certain pattern, which may be due to imbalances in the training data or limitations in the model architecture. Possible improvements include:
#
# - Finding a more diversed training data in terms of the fonts and character patterns
# - Augmenting the data, by artificially diversifying the dataset
# - Trying out a different model architecture
# - Checking and preventing label imbalance
# - Adjusting the post-processing techniques

# %%
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
from sklearn.metrics import *
def get_measures(args):
    loader = torch.utils.data.DataLoader(args['data'],
                batch_size=args['batch_size'],
                collate_fn=args['collate_fn'])
    model = args['model']
    model.eval()
    converter = OCRLabelConverter(args['alphabet'])
    evaluator = Eval()
    labels, predictions, images = [], [], []
    for iteration, batch in enumerate(tqdm(loader)):
        input_, targets = batch['img'].to(device), batch['label']
        images.extend(input_.squeeze().detach())
        labels.extend(targets)
        targets, lengths = converter.encode(targets)
        logits = model(input_).transpose(1, 0)
        logits = torch.nn.functional.log_softmax(logits, 2)
        logits = logits.contiguous().cpu()
        T, B, H = logits.size()
        pred_sizes = torch.LongTensor([T for i in range(B)])
        probs, pos = logits.max(2)
        pos = pos.transpose(1, 0).contiguous().view(-1)
        sim_preds = converter.decode(pos.data, pred_sizes.data, raw=False)
        predictions.extend(sim_preds)
#     make_grid(images[:10], nrow=2)
    fig=plt.figure(figsize=(8, 8))
    columns = 4
    rows = 5
    pairs = list(zip(images, predictions))
    indices = np.random.permutation(len(pairs))
    for i in range(1, columns*rows +1):
        img = images[indices[i]]
        img = (img - img.min())/(img.max() - img.min())
        img = np.array(img * 255.0, dtype=np.uint8)
        fig.add_subplot(rows, columns, i)
        plt.title(predictions[indices[i]])
        plt.axis('off')
        plt.imshow(img)
    plt.show()
    ca = np.mean((list(map(evaluator.char_accuracy, list(zip(predictions, labels))))))
    
    labels_characters = []
    for label in labels:
        label_characters = list(label)
        labels_characters.append(label_characters)
        
    predictions_characters = []
    for prediction in predictions:
        prediction_characters = list(prediction)
        predictions_characters.append(prediction_characters)
        
    predictions_labels_characters = list(zip(labels_characters, predictions_characters))
     
    character_precision_list = []
    character_micro_recall_list = []
    character_macro_recall_list = []
    character_micro_f1_list = []
    character_macro_f1_list = []
    for label, prediction in predictions_labels_characters:
        character_precision = []
        character_micro_recall = []
        character_macro_recall = []
        character_micro_f1 = []
        character_macro_f1 = []
        if len(label) <= len(prediction):
            binary_predictions = [1 if l == p else 0 for l, p in zip(label, prediction)]
            binary_ground_truth = [1] * len(label)
            character_precision.append(precision_score(binary_ground_truth, binary_predictions) * 100)
            character_micro_recall.append(recall_score(binary_ground_truth, binary_predictions, average="micro") * 100)
            character_macro_recall.append(recall_score(binary_ground_truth, binary_predictions, average="macro") * 100)
            character_micro_f1.append(f1_score(binary_ground_truth, binary_predictions, average="micro") * 100)
            character_macro_f1.append(f1_score(binary_ground_truth, binary_predictions, average="macro") * 100)
        elif len(label) > len(prediction):
            prediction = prediction + ["unk"] * (len(label) - (len(prediction)))
            binary_predictions = [1 if l == p else 0 for l, p in zip(label, prediction)]
            binary_ground_truth = [1] * len(label)
            character_precision.append(precision_score(binary_ground_truth, binary_predictions) * 100)
            character_micro_recall.append(recall_score(binary_ground_truth, binary_predictions, average="micro") * 100)
            character_macro_recall.append(recall_score(binary_ground_truth, binary_predictions, average="macro") * 100)
            character_micro_f1.append(f1_score(binary_ground_truth, binary_predictions, average="micro") * 100)
            character_macro_f1.append(f1_score(binary_ground_truth, binary_predictions, average="macro") * 100)
        character_precision_list.append(character_precision)
        character_micro_recall_list.append(character_micro_recall)
        character_macro_recall_list.append(character_macro_recall)
        character_micro_f1_list.append(character_micro_f1)
        character_macro_f1_list.append(character_macro_f1)
            
    average_character_precision = np.mean(character_precision_list)
    average_character_micro_recall = np.mean(character_micro_recall_list)
    average_character_macro_recall = np.mean(character_macro_recall_list)
    average_character_micro_f1 = np.mean(character_micro_f1_list)
    average_character_macro_f1 = np.mean(character_macro_f1_list)
    
    return ca, average_character_precision, average_character_micro_recall, average_character_macro_recall, average_character_micro_f1, average_character_macro_f1

# %%
args['imgdir'] = 'images/test'
args['labeldir'] = 'annotations/test'
args['data'] = SynthDataset(args)
resume_file = os.path.join(args['save_dir'], args['name'], 'best.ckpt')
if os.path.isfile(resume_file):
    print('Loading model %s'%resume_file)
    checkpoint = torch.load(resume_file)
    model.load_state_dict(checkpoint['state_dict'])
    args['model'] = model
    ca, precision, micro_recall, macro_recall, micro_f1, macro_f1 = get_measures(args)
    print("Character Accuracy: %.2f"%(ca), "\nAverage character precision:", precision, "\nAverage character micro recall:", micro_recall, "\nAverage character macro recall:", macro_recall, "\nAverage character micro f1 score:", micro_f1, "\nAverage character macro f1 score:", macro_f1)
else:
    print("=> no checkpoint found at '{}'".format(os.path.join(args['save_dir'], args['name'])))
    print('Exiting')
# Out:
# Loading model ../checkpoints/exp1/best.ckpt
# 100%|██████████| 6/6 [00:01<00:00,  4.54it/s]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Character Accuracy: 12.93
# Average character precision: 61.904761904761905
# Average character micro recall: 9.563492063492063
# Average character macro recall: 4.781746031746032
# Average character micro f1 score: 9.563492063492065
# Average character macro f1 score: 8.162578162578162
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
